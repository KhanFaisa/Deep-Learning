# %% [markdown]
# <a href="https://colab.research.google.com/github/KhanFaisa/Deep-Learning/blob/main/Binary_Classification_With_Keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Read The Train Dataset

# %%
import pandas as pd
url1 = "https://raw.githubusercontent.com/utkarshg1/Neural-Net-Datasets/main/booking_train.csv"
df = pd.read_csv(url1)
df.head()
# Out:
#    id  no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0   0             2               0                     0                  2
# 1   1             2               0                     1                  2
# 2   2             2               0                     0                  1
# 3   3             1               0                     0                  2
# 4   4             2               0                     1                  0
#
#    type_of_meal_plan  required_car_parking_space  room_type_reserved  \
# 0                  1                           0                   0
# 1                  0                           0                   0
# 2                  0                           0                   0
# 3                  1                           0                   0
# 4                  0                           0                   0
#
#    lead_time  arrival_year  arrival_month  arrival_date  market_segment_type  \
# ...

# %% [markdown]
# Booking Status Is Target feature
# 1. 0 - Not Cancelled
# 2. 1 - Cancelled

# %% [markdown]
# ### Step 2 : Perfom Basic Data Quality Checks

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42100 entries, 0 to 42099
# Data columns (total 19 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   id                                    42100 non-null  int64
#  1   no_of_adults                          42100 non-null  int64
#  2   no_of_children                        42100 non-null  int64
#  3   no_of_weekend_nights                  42100 non-null  int64
#  4   no_of_week_nights                     42100 non-null  int64
#  5   type_of_meal_plan                     42100 non-null  int64
#  6   required_car_parking_space            42100 non-null  int64
#  7   room_type_reserved                    42100 non-null  int64
#  8   lead_time                             42100 non-null  int64
#  9   arrival_year                          42100 non-null  int64
#  10  arrival_month                         42100 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# id                                      0
# no_of_adults                            0
# no_of_children                          0
# no_of_weekend_nights                    0
# no_of_week_nights                       0
# type_of_meal_plan                       0
# required_car_parking_space              0
# room_type_reserved                      0
# lead_time                               0
# arrival_year                            0
# arrival_month                           0
# arrival_date                            0
# market_segment_type                     0
# repeated_guest                          0
# no_of_previous_cancellations            0
# no_of_previous_bookings_not_canceled    0
# avg_price_per_room                      0
# no_of_special_requests                  0
# booking_status                          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Step 3 : Seprate X & Y (Booking_Status)

# %%
X = df.drop(columns=['id', 'booking_status'])
Y = df[['booking_status']]

# %%
X.head()
# Out:
#    no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0             2               0                     0                  2
# 1             2               0                     1                  2
# 2             2               0                     0                  1
# 3             1               0                     0                  2
# 4             2               0                     1                  0
#
#    type_of_meal_plan  required_car_parking_space  room_type_reserved  \
# 0                  1                           0                   0
# 1                  0                           0                   0
# 2                  0                           0                   0
# 3                  1                           0                   0
# 4                  0                           0                   0
#
#    lead_time  arrival_year  arrival_month  arrival_date  market_segment_type  \
# ...

# %%
Y.head()
# Out:
#    booking_status
# 0               0
# 1               0
# 2               0
# 3               0
# 4               1

# %%
Y.value_counts()
# Out:
# booking_status
# 0                 25596
# 1                 16504
# Name: count, dtype: int64

# %%
Y.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='booking_status'>

# %% [markdown]
# ### Step 4 : Apply Preprocessing On X

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

# %%
num_pipe = Pipeline(steps=[('impute', SimpleImputer(strategy='median')),
                           ('scaler', StandardScaler())]).set_output(transform='pandas')

# %%
X_pre = num_pipe.fit_transform(X)
X_pre.head()
# Out:
#    no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0      0.151040       -0.313454             -0.998814          -0.278849
# 1      0.151040       -0.313454              0.130259          -0.278849
# 2      0.151040       -0.313454             -0.998814          -0.979466
# 3     -1.753925       -0.313454             -0.998814          -0.278849
# 4      0.151040       -0.313454              0.130259          -1.680084
#
#    type_of_meal_plan  required_car_parking_space  room_type_reserved  \
# 0           1.294624                   -0.160945           -0.515173
# 1          -0.407020                   -0.160945           -0.515173
# 2          -0.407020                   -0.160945           -0.515173
# 3           1.294624                   -0.160945           -0.515173
# 4          -0.407020                   -0.160945           -0.515173
#
#    lead_time  arrival_year  arrival_month  arrival_date  market_segment_type  \
# ...

# %% [markdown]
# ### Step 5 : Perform Train Test Split

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(X_pre, Y, test_size=0.2, random_state=42)

# %%
xtrain.head()
# Out:
#        no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 15559      0.151040       -0.313454             -0.998814           0.421768
# 32783      0.151040       -0.313454              0.130259           1.122386
# 11797      2.056005       -0.313454             -0.998814           0.421768
# 39750      0.151040       -0.313454             -0.998814          -0.979466
# 28711      0.151040       -0.313454              1.259332           0.421768
#
#        type_of_meal_plan  required_car_parking_space  room_type_reserved  \
# 15559          -0.407020                   -0.160945            0.685890
# 32783          -0.407020                   -0.160945            0.685890
# 11797          -0.407020                   -0.160945            0.685890
# 39750           2.996268                   -0.160945           -0.515173
# 28711          -0.407020                   -0.160945            0.685890
#
#        lead_time  arrival_year  arrival_month  arrival_date  \
# ...

# %%
ytrain.head()
# Out:
#        booking_status
# 15559               0
# 32783               0
# 11797               1
# 39750               1
# 28711               1

# %%
xtest.head()
# Out:
#        no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 8768        0.15104       -0.313454             -0.998814           0.421768
# 38340       0.15104       -0.313454             -0.998814          -0.278849
# 7104        0.15104       -0.313454              1.259332          -0.979466
# 36898       0.15104        1.908162              1.259332           1.122386
# 9747        0.15104       -0.313454              1.259332           0.421768
#
#        type_of_meal_plan  required_car_parking_space  room_type_reserved  \
# 8768            -0.40702                   -0.160945           -0.515173
# 38340           -0.40702                   -0.160945           -0.515173
# 7104            -0.40702                   -0.160945            4.289080
# 36898           -0.40702                   -0.160945           -0.515173
# 9747            -0.40702                   -0.160945           -0.515173
#
#        lead_time  arrival_year  arrival_month  arrival_date  \
# ...

# %%
ytest.head()
# Out:
#        booking_status
# 8768                0
# 38340               1
# 7104                0
# 36898               0
# 9747                0

# %%
xtrain.shape
# Out:
# (33680, 17)

# %%
xtest.shape
# Out:
# (8420, 17)

# %% [markdown]
# ### Step 6 : Build The Neural Network

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
xtrain.shape[1]
# Out:
# 17

# %%
from keras.models import Sequential
from keras.layers import Input, Dense, Dropout

# %%
# Intialize the model
model = Sequential()
# Add input layer 1
model.add(Input(shape=(xtrain.shape[1],)))
# Add Hidden Layer 1
model.add(Dense(units=64, activation='relu'))
# Add Dropout layer 1
model.add(Dropout(rate=0.4))
# Add Hidden Layer 2
model.add(Dense(units=32, activation='relu'))
# Add Dropout Layer 2
model.add(Dropout(rate=0.3))
# Add Output Layer
model.add(Dense(units=1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 64)                1152
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 1)                 33
#
# ...
# Total params: 3265 (12.75 KB)
# Trainable params: 3265 (12.75 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
hist = model.fit(xtrain, ytrain, validation_split=0.2, epochs=60)
# Out:
# Epoch 1/60
# 842/842 [==============================] - 8s 5ms/step - loss: 0.5223 - accuracy: 0.7392 - val_loss: 0.4826 - val_accuracy: 0.7718
# Epoch 2/60
# 842/842 [==============================] - 3s 4ms/step - loss: 0.4863 - accuracy: 0.7694 - val_loss: 0.4732 - val_accuracy: 0.7787
# Epoch 3/60
# 842/842 [==============================] - 3s 4ms/step - loss: 0.4783 - accuracy: 0.7784 - val_loss: 0.4706 - val_accuracy: 0.7806
# Epoch 4/60
# 842/842 [==============================] - 3s 3ms/step - loss: 0.4733 - accuracy: 0.7784 - val_loss: 0.4672 - val_accuracy: 0.7859
# Epoch 5/60
# 842/842 [==============================] - 4s 5ms/step - loss: 0.4700 - accuracy: 0.7811 - val_loss: 0.4653 - val_accuracy: 0.7843
# Epoch 6/60
# 842/842 [==============================] - 3s 4ms/step - loss: 0.4667 - accuracy: 0.7847 - val_loss: 0.4641 - val_accuracy: 0.7890
# Epoch 7/60
# ...

# %% [markdown]
# ### Plot The Learning Curve

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5))
plt.plot(hist.history['loss'], label='Train Loss')
plt.plot(hist.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Binary Crossentropy')
plt.title('Learning Curve')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### Evaluate Model In Train & Test

# %%
model.evaluate(xtrain, ytrain)
# Out:
# 1053/1053 [==============================] - 2s 2ms/step - loss: 0.4225 - accuracy: 0.8091
# [0.4225086569786072, 0.8091152310371399]

# %%
model.evaluate(xtest, ytest)
# Out:
# 264/264 [==============================] - 1s 5ms/step - loss: 0.4305 - accuracy: 0.8068
# [0.430492103099823, 0.806769609451294]

# %% [markdown]
# ### Predict the Results For Train And Test

# %%
yprob_train = model.predict(xtrain)
yprob_test = model.predict(xtest)
# Out:
# ...
# 264/264 [==============================] - 0s 2ms/step

# %%
yprob_train[0:5]
# Out:
# array([[0.00879529],
#        [0.1357058 ],
#        [0.7977532 ],
#        [0.74337417],
#        [0.8193436 ]], dtype=float32)

# %%
yprob_test[0:5]
# Out:
# array([[0.04445516],
#        [0.8886575 ],
#        [0.39374015],
#        [0.0164654 ],
#        [0.24941708]], dtype=float32)

# %%
ypred_train = [1 if prob>=0.5 else 0 for prob in yprob_train]
ypred_test = [1 if prob>=0.5 else 0 for prob in yprob_test]

# %%
ypred_train[0:5]
# Out:
# [0, 0, 1, 1, 1]

# %%
ytrain.head()
# Out:
#        booking_status
# 15559               0
# 32783               0
# 11797               1
# 39750               1
# 28711               1

# %%
ypred_test[0:5]
# Out:
# [0, 1, 0, 0, 0]

# %%
ytest.head()
# Out:
#        booking_status
# 8768                0
# 38340               1
# 7104                0
# 36898               0
# 9747                0

# %% [markdown]
# ### Plot Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cf = confusion_matrix(ytest, ypred_test)
cfd = ConfusionMatrixDisplay(cf)
cfd.plot()

# %%
from sklearn.metrics import classification_report
print(classification_report(ytest, ypred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.88      0.85      5150
#            1       0.78      0.70      0.74      3270
#
#     accuracy                           0.81      8420
#    macro avg       0.80      0.79      0.79      8420
# weighted avg       0.81      0.81      0.80      8420

# %% [markdown]
# ### Above Model Is Good Because It Has Good Accuracy Of 0.81> 0.8

# %%
model.save('BookingModel.keras')

# %% [markdown]
# ### Loading Model

# %%
from keras.models import load_model
m = load_model('/content/BookingModel.keras')
m.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 64)                1152
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 1)                 33
#
# ...
# Total params: 3265 (12.75 KB)
# Trainable params: 3265 (12.75 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Out Of Sample Prediction

# %%
url2 = "https://raw.githubusercontent.com/utkarshg1/Neural-Net-Datasets/main/booking_test.csv"
xnew = pd.read_csv(url2)
xnew.head()
# Out:
#       id  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0  42100             3               0                     1
# 1  42101             2               0                     0
# 2  42102             2               2                     0
# 3  42103             2               0                     0
# 4  42104             1               0                     0
#
#    no_of_week_nights  type_of_meal_plan  required_car_parking_space  \
# 0                  4                  0                           0
# 1                  3                  0                           0
# 2                  1                  0                           0
# 3                  3                  0                           0
# 4                  2                  2                           0
#
#    room_type_reserved  lead_time  arrival_year  arrival_month  arrival_date  \
# 0                   1        111          2018             12             5
# ...

# %%
xnew2 = xnew.drop(columns=['id'])

# %%
num_pipe
# Out:
# Pipeline(steps=[('impute', SimpleImputer(strategy='median')),
#                 ('scaler', StandardScaler())])

# %%
xnew_pre = num_pipe.transform(xnew2)
xnew_pre.head()
# Out:
#    no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0      2.056005       -0.313454              0.130259           1.122386
# 1      0.151040       -0.313454             -0.998814           0.421768
# 2      0.151040        4.129777             -0.998814          -0.979466
# 3      0.151040       -0.313454             -0.998814           0.421768
# 4     -1.753925       -0.313454             -0.998814          -0.278849
#
#    type_of_meal_plan  required_car_parking_space  room_type_reserved  \
# 0          -0.407020                   -0.160945            0.685890
# 1          -0.407020                   -0.160945           -0.515173
# 2          -0.407020                   -0.160945            3.088017
# 3          -0.407020                   -0.160945           -0.515173
# 4           2.996268                   -0.160945           -0.515173
#
#    lead_time  arrival_year  arrival_month  arrival_date  market_segment_type  \
# ...

# %%
probs = model.predict(xnew_pre)
probs[0:5]
# Out:
# 878/878 [==============================] - 3s 3ms/step
# array([[0.077599  ],
#        [0.02949031],
#        [0.4080679 ],
#        [0.16538802],
#        [0.6459386 ]], dtype=float32)

# %%
preds = [1 if prob>=0.5 else 0 for prob in probs]
preds[0:5]
# Out:
# [0, 0, 0, 0, 1]

# %% [markdown]
# ### Save Above Results In Dataframe

# %%
df_final = xnew[['id']]
df_final
# Out:
#           id
# 0      42100
# 1      42101
# 2      42102
# 3      42103
# 4      42104
# ...      ...
# 28063  70163
# 28064  70164
# 28065  70165
# 28066  70166
# 28067  70167
#
# [28068 rows x 1 columns]

# %%
df_final['booking_status'] = preds
df_final['probability'] = probs
# Out:
# <ipython-input-48-92bd6e8c5ada>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['booking_status'] = preds
# <ipython-input-48-92bd6e8c5ada>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['probability'] = probs

# %%
df_final
# Out:
#           id  booking_status  probability
# 0      42100               0     0.077599
# 1      42101               0     0.029490
# 2      42102               0     0.408068
# 3      42103               0     0.165388
# 4      42104               1     0.645939
# ...      ...             ...          ...
# 28063  70163               1     0.956502
# 28064  70164               0     0.051048
# 28065  70165               0     0.162805
# 28066  70166               0     0.456550
# 28067  70167               1     0.792971
#
# [28068 rows x 3 columns]

# %%
df_final['booking_status'].value_counts()
# Out:
# booking_status
# 0    18331
# 1     9737
# Name: count, dtype: int64

# %%
df_final['booking_status'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='booking_status'>

# %% [markdown]
# ### Save the Datframe To CSV Format

# %%
df_final.to_csv('BookingResults.csv', index=False)
